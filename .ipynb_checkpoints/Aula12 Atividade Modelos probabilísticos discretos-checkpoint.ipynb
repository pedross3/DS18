# %% [markdown]
#  ___
# # Atividade: Modelos probabilísticos discretos
# ___
#
# ## Aula 12
#
# **Referência de Leitura:**
# 1. Magalhães e Lima (7ª. Edição): Seções 3.2 e 3.3
#
# **Hoje:**
# 1.	Descrever modelos discretos quanto aos resultados teóricos.
# 2.	Explicar a utilização de modelos probabilísticos no contexto da literatura estatística.
# 3.	Contrastar resultados teóricos e empíricos.
# 4.	Fechamento do conteúdo.
#
# **Próxima aula:**
# 1. Leitura prévia necessária: Magalhães e Lima (7ª. Edição): Capítulo 6 - Seção 6.1.
#
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

from scipy import stats #importa apenas as funções de estatísticas da biblioteca SciPy.
import itertools #importante para gerar todos os resultados possíveis!!

# %% [markdown]
# A seguir, um resumo sobre o modelo teórico Binomial!
# >
#
# > **DISTRIBUIÇÃO BINOMIAL - TEORIA:**
#
# > É responsável por modelar uma variável $Y$ definida pelo Número de sucessos em $n$ tentativas, cuja probabilidade de sucesso é dada por $p$. Assim, dizemos que $Y$~$Bin(n,p)$ e lê-se: $Y$ segue uma distribuição binomial com $n$ tentativas e $p$ como probabilidade de sucesso.
#
# > A função de probabilidade nesse caso é dada por:
# $P(Y=y)=\left(
# \begin{array}{c}
#     n \\
#     y
# \end{array}\right) p^y (1-p)^{(n-y)}$
#
# > Para um experimento ter as probabilidade dos números de sucessos modeladas por uma distribuição Binomial, o mesmo precisa ter as seguintes propriedades:
# * é uma contagem de $n$ repetições (ou tentativas ou ensaios) idênticas;
# * cada repetição tem apenas 2 resultados possíveis: um é denominado sucesso e o outro, fracasso;
# * a probabilidade de sucesso para cada ensaio é denominada $p$ e será constante em cada repetição. Então, a probabilidade de fracasso $(1-p)$ também não varia de tentativa para tentativa;
# * As tentativas são independentes.
#
#
# > **DISTRIBUIÇÃO BINOMIAL - PYTHON:** <sup> [https://en.wikipedia.org/wiki/SciPy]
#
# > Algumas funções úteis para desenvolver seu código: <sup> [http://docs.scipy.org/doc/scipy-0.16.1/reference/generated/scipy.stats.binom.html]
# * $P(Y=y)$: `stats.binom.pmf(y, n, p)`
# * $P(Y\leq y)$: `stats.binom.cdf(y, n, p)`
# * $E(Y)$ e $Var(Y)$: `stats.binom.stats(n, p, moments='mv')`

# %% [markdown]
# ___
# ## <font color='blue'>Exercício 1</font>
#
# ### <font color='red'>**Publicar no github até dia 10/04 INDIVIDUAL **</font>
#
#
# #### Este exercício irá explorar  construção de árvore de probabilidades com eventos e construção da distribuição de probabilidades de uma variável aleatória discreta. Ainda, irá explorar o modelo de distribuição probabilística Binomial
#
# Um resistor de 100K Ohms comprado na Santa Efigênia tem probabilidade de falha de 5%, segundo um fabricante ruim.
#
# Ainda, por suposição, admita que os resistores falhem de forma independente entre si.
#
# Um aluno de engenharia compra um pacote contendo $n$ resistores.
#
# 1. Assuma $n=3$ e faça os itens a seguir.
#   1. Monte o espaço amostral que combine todos os resultados possíveis de Falha e não Falha desses $n$ resistores. Ainda, calcule a probabilidade de cada resultado do espaço amostral acontecer.
#   2. Se $Y$ representa o número de resistores que falham em um pacotinho com $n$ resistores, então construa a distribuição de probabilidades de $Y$.
#   3. Calcule a média e o desvio padrão de $Y$. Interprete os resultados.
#   4. Utilizando o modelo probabilístico da distribuição Binomial, encontre a distribuição de probabilidades de cada possível valor de $Y$. Calcule também $E(Y)$ e $Var(Y)$. Compare com as distribuições de probabilidades obtidas nos itens anteriores e discuta porque esses valores são iguais ou diferentes!
#
# 2. Assuma $n=7$ e repita os itens A) a D) anteriores. No caso de $n=7$ ou maiores quantidades de resistores em um pacotinho, qual a viabilidade de construir a distribuição de probabilidades do número de resistores com defeitos quando $n$ não é pequeno seguindo os itens de A) a C)?
#
# 3. Com $n=100$, por exemplo, é extremamente inviável a construção de árvore de probabilidades até mesmo utilizando a poderosa ferramenta Python.
#   1. No caso assuma $n=100$ e repita o item 1.D) anterior.
#   2. Ainda, calcule a probabilidade de, em um pacote com 100 resistores, pelo menos a metade deles apresentarem falha.

# %%
import itertools

# %%
#item 1
n=37
possibilidades = ["Funciona", "Defeito"]
prob = {"Funciona": 0.95, "Defeito": 0.05}
arranjos = itertools.product(possibilidades, repeat=n)
espaço_amostral = list(arranjos) #Cria uma lista com todas as combinações

# %%
prob_linhas = []

for comb in espaço_amostral:
    p = 1.0
    for evento in res:
        p*=prob[evento]
    prob_linhas.append(p)

# %% [markdown]
# Somando as probabilidades:

# %%
valores_Y = {}
for i in range(len(espaço_amostral)):
    y = espaço_amostral[i].count("Funciona")
    # Checar antes se a chave está no dicionário
    if y in valores_Y:
        valores_Y[y] += prob_linhas[i]
    else:
        valores_Y[y] = prob_linhas[i]

# %%
valores_Y
# Out:
# {0: 0.00012500000000000003,
#  1: 0.007125000000000001,
#  2: 0.135375,
#  3: 0.8573749999999999}

# %%
"%3.5f"%sum(prob_linhas)
# Out:
# '1.00000'

# %% [markdown]
# # Item 2

# %%
#item 2
n=7
possibilidades2 = ["Funciona", "Defeito"]
prob2 = {"Funciona": 0.95, "Defeito": 0.05}
arranjos2 = itertools.product(possibilidades2, repeat=n)
espaço_amostral2 = list(arranjos2)
# Out:
# [('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Funciona'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona',
#   'Defeito'),
#  ('Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Defeito',
#   'Funciona'),
#  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito')]

# %%
prob_linhas2 = []

for comb in espaço_amostral2:
    p2 = 1.0
    
    for evento in comb:
        p2*=prob2[evento]
        
    prob_linhas2.append(p)
    print("Probabilidade de ",comb," é igual a ","%3.5f"%p2)
# Out:
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.69834
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.03675
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00193
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00010
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Funciona')  é igual a  0.00001
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona', 'Defeito')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Funciona')  é igual a  0.00000
# Probabilidade de  ('Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito', 'Defeito')  é igual a  0.00000

# %%
valores_X = {}
for i in range(len(espaço_amostral2)):
    x = espaço_amostral2[i].count("Funciona")
    
    if x in valores_X:
        valores_X[x] += prob_linhas2[i]
    else:
        valores_X[x] = prob_linhas2[i]

# %%
print(sum(prob_linhas2))
# Out:
# 0.01600000000000001

# %% [markdown]
# ___
# ## <font color='blue'>Exercício 2</font>
#
# Esse exercício irá explorar modelos de distribuição de Poisson.
#
# Uma fábrica produz determinado veículo. O gerente de vendas fechou um negócio que implica na produção de pelo menos 110 unidades nos próximos dois meses. Para isso, será construída uma nova linha de montagem com capacidade para produzir em média 50 veículos por mês (considere meses de 30 dias). A linha funcionará ininterruptamente. Além disso, apenas um veículo é produzido por vez. Considere que um modelo Poisson seja adequado para a quantidade de veículos produzidos.
#    1. Qual a probabilidade  da produção ser igual a 100 veículos nos próximos dois meses?
#    2. Qual a probabilidade  da produção ser de pelo menos 100 veículos nos próximos dois meses?
#    3. Qual a probabilidade da produção ser entre 100 e 110 veículos nos próximos dois meses?
#    4. Se forem produzidos de pelo menos 100 veículos no próximo mês, qual a probabilidade do gerente cumprir a meta negociada?
#    5. Caso o prazo seja cumprido, o lucro será da ordem de $250$ mil, caso não seja, o lucro cai para $200$ mil. Qual é o lucro esperado e seu desvio-padrão?
#
# **Observação:** Explore os comandos de `stats.poisson`. <sup>[http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html]
